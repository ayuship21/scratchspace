# %%
import pandas as pd
spreadsheet = pd.read_csv('Water Chemistry.csv')
spreadsheet
# Out:
#         SITE_ID  Chla ug/L  DIN mg N/L  DIP mg P/L  DO mg/L  \
# 0     AL00-0001       8.10       0.005       0.031     6.00
# 1     AL00-0002      14.00       0.010       0.038     6.80
# 2     AL00-0003      12.00       0.022       0.059     5.10
# 3     AL00-0004      19.00       0.007       0.006     4.10
# 4     AL00-0005       8.10       0.015       0.028     5.70
# ...         ...        ...         ...         ...      ...
# 3197  WA99-0046       3.48       0.095       0.009     8.12
# 3198  WA99-0047       4.01       0.109       0.011     8.97
# 3199  WA99-0048       1.13       0.041       0.000    10.83
# 3200  WA99-0049       6.50       0.113       0.010     9.72
# 3201  WA99-0050      19.09       0.109       0.009     8.93
#
#       Light transmittance (%) @ 1 m Chla Cond DIN Cond DIP Cond DO Cond  ...  \
# 0                             14.29      FAIR     GOOD     FAIR    GOOD  ...
# 1                             18.89      FAIR     GOOD     FAIR    GOOD  ...
# ...

# %%
plt.show()import pandas as pd
from matplotlib import pyplot as plt

# Set the figure size
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

# Make a list of columns
columns = ['Chla ug/L', 'DIN mg N/L', 'DIP mg P/L', 'DO mg/L']

# Read a CSV file
df = pd.read_csv("Water Chemistry.csv", usecols=columns)

# Plot the lines
df.plot(linewidth = '0.4')

# %%
spreadsheet = pd.read_csv('Barron River.csv')
spreadsheet
# Out:
#                      time  z  sea_water_electrical_conductivity  \
# 0    2023-07-05T12:45:00Z  0                              45700
# 1    2023-07-05T12:30:00Z  0                              46300
# 2    2023-07-05T12:15:00Z  0                              47100
# 3    2023-07-05T12:00:00Z  0                              48400
# 4    2023-07-05T11:45:00Z  0                              48400
# ..                    ... ..                                ...
# 316  2023-07-02T05:45:00Z  0                              37200
# 317  2023-07-02T05:30:00Z  0                              36500
# 318  2023-07-02T05:15:00Z  0                              36100
# 319  2023-07-02T05:00:00Z  0                              35800
# 320  2023-07-02T04:45:00Z  0                              35200
#
#      sea_water_practical_salinity  height_geoid_local_station_datum  \
# 0                              30                          0.045720
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Set the figure size
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

# Make a list of columns
columns = ['sea_water_practical_salinity', 'sea_water_temperature']

# Read a CSV file
df = pd.read_csv("Barron River.csv", usecols=columns)

# Plot the lines
df.plot(linewidth = '0.4')

plt.show()

# %%
spreadsheet = pd.read_csv('ClimChangeNew.csv')
spreadsheet
# Out:
#      Date  Much Above Normal  Much Below Normal
# 0    1910               10.2                3.6
# 1    1911               10.8               18.9
# 2    1912                0.0               61.5
# 3    1913                1.8               28.3
# 4    1914                0.0               11.3
# ..    ...                ...                ...
# 108  2018               20.6                0.3
# 109  2019               10.1                9.5
# 110  2020               46.9                0.0
# 111  2021               52.2                0.0
# 112  2022               25.6                0.0
#
# [113 rows x 3 columns]

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Set the figure size
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

# Make a list of columns
columns = ['Much Above Normal', 'Much Below Normal']

# Read a CSV file
df = pd.read_csv("ClimChangeNew.csv", usecols=columns)

# Plot the lines
df.plot(linewidth = '0.4')

plt.show()

# %%
spreadsheet = pd.read_csv('anomalies.csv')
spreadsheet
# Out:
#        Date  Trmperature  Anomaly
# 0    189506        67.80    -0.69
# 1    189606        69.89     1.40
# 2    189706        68.11    -0.38
# 3    189806        69.31     0.82
# 4    189906        68.65     0.16
# ..      ...          ...      ...
# 124  201906        68.72     0.23
# 125  202006        70.29     1.80
# 126  202106        72.59     4.10
# 127  202206        70.81     2.32
# 128  202306        69.03     0.54
#
# [129 rows x 3 columns]

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Set the figure size
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

# Make a list of columns
columns = ['Trmperature']

# Read a CSV file
df = pd.read_csv("anomalies.csv", usecols=columns)

# Plot the lines
df.plot(linewidth = '0.4')

plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Set the figure size
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

# Make a list of columns
columns = ['Anomaly']

# Read a CSV file
df = pd.read_csv("anomalies.csv", usecols=columns)

# Plot the lines
df.plot(linewidth = '0.4')

plt.show()
